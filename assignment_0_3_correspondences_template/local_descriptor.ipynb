# %% [markdown]
# # Lab 2: Local feature description
# This is a notebook, which could help you with testing third lab assignment.
# It contains utility functions for visualization, some test input for the functions you needs to implement,
# and the output of the reference solution for the same test input.
#
# template functions for the assignment contain a short description of what the function is supposed to do,
# and produce an incorrect output, which is nevertheless in proper format: type and shape.
#
# You are not allowed to use kornia or opencv or any other library functions, which are specifically designed
# to perform the operations requested in assignment

# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import numpy as np
import torch
import kornia
import cv2
import os
from PIL import Image
import kornia as K


def plot_torch(x, y, *kwargs):
    plt.plot(x.detach().cpu().numpy(), y.detach().cpu().numpy(), *kwargs)
    return

def imshow_torch(tensor,figsize=(8,6), *kwargs):
    plt.figure(figsize=figsize)
    plt.imshow(kornia.tensor_to_image(tensor), *kwargs)
    return

def imshow_torch_channels(tensor, dim = 1, *kwargs):
    num_ch = tensor.size(dim)
    fig=plt.figure(figsize=(num_ch*5,5))
    tensor_splitted = torch.split(tensor, 1, dim=dim)
    for i in range(num_ch):
        fig.add_subplot(1, num_ch, i+1)
        plt.imshow(kornia.tensor_to_image(tensor_splitted[i].squeeze(dim)), *kwargs)
    return

def timg_load(fname, to_gray = True):
    img = cv2.imread(fname)
    with torch.no_grad():
        timg = kornia.image_to_tensor(img, False).float()
        if to_gray:
            timg = kornia.color.bgr_to_grayscale(timg)
        else:
            timg = kornia.color.bgr_to_rgb(timg)
    return timg


def visualize_detections(img, keypoint_locations, img_idx = 0, increase_scale = 1.):
    # Select keypoints relevant to image   
    kpts = [cv2.KeyPoint(b_ch_sc_y_x[4].item(),
                         b_ch_sc_y_x[3].item(),
                         increase_scale * b_ch_sc_y_x[2].item(), 90)
            for b_ch_sc_y_x in keypoint_locations if b_ch_sc_y_x[0].item() == img_idx]
    vis_img = None
    vis_img = cv2.drawKeypoints(kornia.tensor_to_image(img).astype(np.uint8),
                                kpts,
                                vis_img, 
                                flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
    plt.figure(figsize=(12,10))
    plt.imshow(vis_img)
    return

# %% [markdown]
# First, we load an image to work with and detect some features

# %%
timg = timg_load('graffiti.ppm', False)/255.
timg_gray = kornia.color.rgb_to_grayscale(timg)
imshow_torch(timg)

from local_descriptor import *
estimate_patch_dominant_orientation(timg_gray)
with torch.no_grad():
    keypoint_locations = scalespace_harris(timg_gray, 0.00001)
    visualize_detections(timg_gray*255., keypoint_locations, increase_scale=16.0)

# %%
keypoint_locations.shape
# Out:
# torch.Size([236, 5])

# %%
from local_descriptor import *

A, img_idxs = affine_from_location(keypoint_locations)

print (f'keypoint_locations={keypoint_locations[50]}')
print (f'A={A[50]}')

idxs = range(50,55)
visualize_detections(timg_gray*255., keypoint_locations[idxs], increase_scale=6.0) 
patches = extract_affine_patches(timg, A[idxs], img_idxs[idxs], 32, 6.0/2.)
# OpenCV visualization treats keypoint scale as diameter, while extract_affine_patches as radius,
# therefore we should divide by two to get same area

imshow_torch_channels(patches, 0)
# Out:
# keypoint_locations=tensor([  0,   0,   1, 296,  96])
# A=tensor([[  1.,   0.,  96.],
#         [  0.,   1., 296.],
#         [  0.,   0.,   1.]])
# C:\Users\toell\OneDrive\Documents\GitHub\mpv-templates-backup\venv\Lib\site-packages\torch\functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ..\aten\src\ATen\native\TensorShape.cpp:3550.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %% [markdown]
# ## Reference example
# ```python
# from local_descriptor import *
#
# A, img_idxs = affine_from_location(keypoint_locations)
#
# print (f'keypoint_locations={keypoint_locations[1000]}')
# print (f'A={A[1000]}')
#
# idxs = range(1000,1005)
# visualize_detections(timg_gray*255., keypoint_locations[idxs], increase_scale=6.0)
# patches = extract_affine_patches(timg, A[idxs], img_idxs[idxs], 32, 6.0/2.)
# # OpenCV visualization treats keypoint scale as diameter, while extract_affine_patches as radius,
# # therefore we should divide by two to get same area
#
# imshow_torch_channels(patches, 0)
# ```
#
# ![image.png](local_descriptor_files/att_00000.png)

# %%
from local_descriptor import *

input_kp_locations = torch.tensor([0, 0, 10., 150, 340]).view(1, 5)
input_orientation = torch.tensor([math.pi / 2.0]).view(1,1)
input_affine_shape = torch.tensor([4., 0., 2.]).view(1,3)

A, img_idxs  = affine_from_location(input_kp_locations)
print (A.long())
A1, img_idxs = affine_from_location_and_orientation(input_kp_locations, input_orientation)
print (A1.long())
A2, img_idxs = affine_from_location_and_orientation_and_affshape(input_kp_locations, 
                                                                 input_orientation,
                                                                 input_affine_shape)
print (A2.long())
# Out:
# tensor([[[ 10,   0, 340],
#          [  0,  10, 150],
#          [  0,   0,   1]]])
# tensor([[[  0,  10, 340],
#          [-10,   0, 150],
#          [  0,   0,   1]]])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 11
#       9 A1, img_idxs = affine_from_location_and_orientation(input_kp_locations, input_orientation)
#      10 print (A1.long())
# ---> 11 A2, img_idxs = affine_from_location_and_orientation_and_affshape(input_kp_locations,
#      12                                                                  input_orientation,
#      13                                                                  input_affine_shape)
#      14 print (A2.long())
#
# File ~\OneDrive\Documents\GitHub\mpv-templates-backup\assignment_0_3_correspondences_template\local_descriptor.py:77, in affine_from_location_and_orientation_and_affshape(b_ch_d_y_x, ori, aff_shape)
#      75 C[:, :2, 0] = aff_shape[:, 2]
#      76 C[:, :2, 1] = aff_shape[:, 1:]
# ---> 77 inv_sqrt_C = torch.linalg.inv(torch.linalg.sqrtm(C))
#      78 # Compute determinant of inverse square root of C
#      79 det_sqrt_inv_C = torch.det(inv_sqrt_C)
#
# AttributeError: module 'torch.linalg' has no attribute 'sqrtm'

# %% [markdown]
# ## Refence example
#
# ```python
# from local_descriptor import *
#
# input_kp_locations = torch.tensor([0, 0, 10., 150, 340]).view(1, 5)
# input_orientation = torch.tensor([math.pi / 2.0]).view(1,1)
# input_affine_shape = torch.tensor([4., 0., 2.]).view(1,3)
#
# A, img_idxs  = affine_from_location(input_kp_locations)
# print (A.long())
# A1, img_idxs = affine_from_location_and_orientation(input_kp_locations, input_orientation)
# print (A1.long())
# A2, img_idxs = affine_from_location_and_orientation_and_affshape(input_kp_locations,
#                                                                  input_orientation,
#                                                                  input_affine_shape)
# print (A2.long())
# ```
#     tensor([[[ 10,   0, 340],
#              [  0,  10, 150],
#              [  0,   0,   1]]])
#     tensor([[[  0,  10, 340],
#              [-10,   0, 150],
#              [  0,   0,   1]]])
#     tensor([[[  0,   8, 340],
#              [-11,   0, 150],
#              [  0,   0,   1]]])

# %% [markdown]
# # Local patch orientation
#
# Script for benchmarking local patch orientation, similar to one in AE

# %%
from local_descriptor import estimate_patch_dominant_orientation 
def normalize_angle(ang):
    #https://stackoverflow.com/a/22949941/1983544
    return ang - (torch.floor((ang + K.pi)/(2.0*K.pi)))*2.0*K.pi;

def benchmark_orientation_consistency(orienter, patches, PS_out, angles=[15], bins=36):
    import kornia as K
    from kornia.geometry.transform import center_crop, rotate
    from kornia.geometry.conversions import rad2deg, deg2rad
    errors = []
    with torch.no_grad():
        patches_orig_crop = center_crop(patches, (PS_out, PS_out))
        ang_out = normalize_angle(orienter(patches_orig_crop, bins))     
        for ang_gt in angles:
            ang_gt = torch.tensor(ang_gt)
            patches_ang = rotate(patches, ang_gt)
            patches_ang_crop = center_crop(patches_ang, (PS_out, PS_out))
            ang_out_ang = normalize_angle(orienter(patches_ang_crop, bins))
            error_aug_cw = normalize_angle(ang_out - deg2rad(ang_gt) - ang_out_ang).abs()
            error_aug_ccw = normalize_angle(ang_out + deg2rad(ang_gt) - ang_out_ang).abs()
            if error_aug_ccw.mean().item() < error_aug_cw.mean().item():
                error_aug = error_aug_ccw
            else:
                error_aug = error_aug_cw
            errors.append(error_aug.mean())
            print (f'mean consistency error = {rad2deg(error_aug.mean()):.1f} [deg]') 
    return rad2deg(torch.stack(errors).mean())

# %% [markdown]
# We can try our orientation estimation function with interactive widget.
# Uncomment the next cell to install necessary packages

# %%
# !pip install celluloid mpl_interactions
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting celluloid
#   Obtaining dependency information for celluloid from https://files.pythonhosted.org/packages/60/a7/7fbe80721c6f1b7370c4e50c77abe31b4d5cfeb58873d4d32f48ae5a0bae/celluloid-0.2.0-py3-none-any.whl.metadata
#   Downloading celluloid-0.2.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting mpl_interactions
#   Obtaining dependency information for mpl_interactions from https://files.pythonhosted.org/packages/59/12/90029214a2f11752228c2eb9eb8a6789c3692f4ff1682733b6a340fbc5d3/mpl_interactions-0.24.1-py3-none-any.whl.metadata
#   Downloading mpl_interactions-0.24.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: matplotlib in c:\users\toell\onedrive\documents\github\mpv-templates-backup\venv\lib\site-packages (from celluloid) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\toell\onedrive\documents\github\mpv-templates-backup\venv\lib\site-packages (from matplotlib->celluloid) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\toell\onedrive\documents\github\mpv-templates-backup\venv\lib\site-packages (from matplotlib->celluloid) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\toell\onedrive\documents\github\mpv-templates-backup\venv\lib\site-packages (from matplotlib->celluloid) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\toell\onedrive\documents\github\mpv-templates-backup\venv\lib\site-packages (from matplotlib->celluloid) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\toell\onedrive\documents\github\mpv-templates-backup\venv\lib\site-packages (from matplotlib->celluloid) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\toell\onedrive\documents\github\mpv-templates-backup\venv\lib\site-packages (from matplotlib->celluloid) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\toell\onedrive\documents\github\mpv-templates-backup\venv\lib\site-packages (from matplotlib->celluloid) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\toell\onedrive\documents\github\mpv-templates-backup\venv\lib\site-packages (from matplotlib->celluloid) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\toell\onedrive\documents\github\mpv-templates-backup\venv\lib\site-packages (from matplotlib->celluloid) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\toell\onedrive\documents\github\mpv-templates-backup\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->celluloid) (1.16.0)
# Downloading celluloid-0.2.0-py3-none-any.whl (5.4 kB)
# Downloading mpl_interactions-0.24.1-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/47.5 kB ? eta -:--:--
#    ---------------------------------------- 47.5/47.5 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: mpl_interactions, celluloid
# Successfully installed celluloid-0.2.0 mpl_interactions-0.24.1
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from kornia_moons.feature import visualize_LAF

# %%
from oriviz import play_with_angle

visualize_LAF(timg, K.feature.scale_laf(A[:,:2,:3].reshape(1,1,2,3), 2.0), color='yellow')
A = torch.tensor([[[ 50., 0., 300.],
                   [ 0., 50., 200.],
                   [ 0.,  0.,   1.]]])


play_with_angle(timg_gray, A, estimate_patch_dominant_orientation)
# Out:
# interactive(children=(FloatSlider(value=0.0, description='Angle:', max=360.0, step=1.0), Output()), _dom_class…

# %% [markdown]
# Now lets load patches and check. Threshold for passing the test is 20 degrees

# %%
dir_fname = 'patches/'
fnames = os.listdir(dir_fname)
angles = [90., 60., 45., 30.]
PS_out = 32
PS = 65


angles = [70., 30.]
orienter = estimate_patch_dominant_orientation
with torch.no_grad():
    errors = []
    for f in fnames[::-1]:
        fname = os.path.join(dir_fname, f)
        patches = K.image_to_tensor(np.array(Image.open(fname).convert("L"))).float() / 255.
        patches = patches.reshape(-1, 1, PS, PS)
        err = benchmark_orientation_consistency(orienter, patches, PS_out, angles)
        errors.append(err)
    AVG_ERR = torch.stack(errors).mean().item()
    print (f'Average error = {AVG_ERR:.1f} deg')
# Out:
# mean consistency error = 0.0 [deg]
# mean consistency error = 10.0 [deg]
# Average error = 5.0 deg

# %% [markdown]
# ## Refence example
#
# ```python
# dir_fname = 'patches/'
# fnames = os.listdir(dir_fname)
# angles = [90., 60., 45., 30.]
# PS_out = 32
# PS = 65
# import sys
# sys.path.insert(0,'/home/old-ufo/dev/BRUTE/mpv-test-04/upload_system/')
# from refence_solution.local_descriptor import estimate_patch_dominant_orientation as REF
#
#
# angles = [70., 30.]
# orienter = REF
# with torch.no_grad():
#     errors = []
#     for f in fnames[::-1]:
#         fname = os.path.join(dir_fname, f)
#         patches = K.image_to_tensor(np.array(Image.open(fname).convert("L"))).float() / 255.
#         patches = patches.reshape(-1, 1, PS, PS)
#         err = benchmark_orientation_consistency(orienter, patches, PS_out, angles)
#         errors.append(err)
#     AVG_ERR = torch.stack(errors).mean().item()
#     print (f'Average error = {AVG_ERR:.1f} deg')
# ```
#
#     mean consistency error = 1.9 [deg]
#     mean consistency error = 3.0 [deg]
#     Average error = 2.4 deg

# %% [markdown]
# ## SIFT descriptor
#
# SIFT descriptor is a histogram of image gradients and used for local patch description.
# For the "realworld" evaluation of the SIFT descriptor, please, use [image-matching-interactive.ipynb](image-matching-interactive.ipynb) notebook.
# We also provide you a tool for descriptor visualization purposes, which might help you to debug the descriptor development.

# %%
from oriviz import visualize_sift
from local_descriptor import calc_sift_descriptor 

patch = torch.zeros(1, 1, 32, 32)
patch[:,:, 16:, :] = 1.0
plt.imshow(K.tensor_to_image(patch))


num_ang_bins = 8
num_spatial_bins = 4

desc = calc_sift_descriptor(patch, num_ang_bins, num_spatial_bins)
desc2 =  K.feature.SIFTDescriptor(32, num_ang_bins, num_spatial_bins)(patch)

fig = visualize_sift(desc, num_ang_bins, num_spatial_bins, 'User SIFT')
fig2 = visualize_sift(desc2, num_ang_bins, num_spatial_bins, 'kornia SIFT')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 13
#      10 num_spatial_bins = 4
#      12 desc = calc_sift_descriptor(patch, num_ang_bins, num_spatial_bins)
# ---> 13 desc2 =  K.feature.SIFTDescriptor(32, num_ang_bins, num_spatial_bins)(patch)
#      15 fig = visualize_sift(desc, num_ang_bins, num_spatial_bins, 'User SIFT')
#      16 fig2 = visualize_sift(desc2, num_ang_bins, num_spatial_bins, 'kornia SIFT')
#
# File ~\OneDrive\Documents\GitHub\mpv-templates-backup\venv\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\OneDrive\Documents\GitHub\mpv-templates-backup\venv\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\OneDrive\Documents\GitHub\mpv-templates-backup\venv\Lib\site-packages\kornia\feature\siftdesc.py:165, in SIFTDescriptor.forward(self, input)
#     163 ang_bins = torch.clamp(ang_bins, 0.0, float(self.clipval))
#     164 ang_bins = normalize(ang_bins, p=2)
# --> 165 if self.rootsift:
#     166     ang_bins = torch.sqrt(normalize(ang_bins, p=1) + self.eps)
#     167 return ang_bins
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:1187, in _pydevd_bundle.pydevd_cython_win32_312_64.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:627, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:1103, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:1065, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:585, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.do_wait_suspend()
#
# File C:\Program Files\JetBrains\PyCharm 2023.3.2\plugins\python\helpers\pydev\pydevd.py:1184, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1181         from_this_thread.append(frame_id)
#    1183 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1184     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File C:\Program Files\JetBrains\PyCharm 2023.3.2\plugins\python\helpers\pydev\pydevd.py:1199, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1196             self._call_mpl_hook()
#    1198         self.process_internal_commands()
# -> 1199         time.sleep(0.01)
#    1201 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1203 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
desc-desc2
# Out:
# tensor([[-4.9918e-03, -5.6764e-03, -5.7204e-03, -5.3868e-03, -5.5116e-03,
#          -6.2676e-03, -6.3161e-03, -5.9477e-03, -5.2145e-03, -5.9297e-03,
#          -5.9756e-03, -5.6271e-03, -5.3868e-03, -6.1256e-03, -6.1731e-03,
#          -5.8130e-03, -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05,
#          -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05,
#          -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05,
#          -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05,  4.6428e-01,
#          -1.0000e-05, -3.0366e-01, -3.4532e-01, -3.4799e-01, -3.2769e-01,
#          -3.7401e-01, -3.7401e-01,  9.0277e-02, -3.7401e-01, -1.0000e-05,
#          -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05,
#           4.6428e-01, -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05,
#          -1.0000e-05, -1.0000e-05, -1.0000e-05,  4.6428e-01, -1.0000e-05,
#          -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05,
#          -1.0000e-05,  1.8557e-01, -1.0000e-05, -1.0000e-05, -1.0000e-05,
#          -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05,  1.8557e-01,
#          -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05,
#          -1.0000e-05, -1.0000e-05,  1.8557e-01, -1.0000e-05, -1.0000e-05,
#          -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05,
#           1.8557e-01, -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05,
#          -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05,
#          -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05,
#          -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05,
#          -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05,
#          -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05,
#          -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05, -1.0000e-05,
#          -1.0000e-05, -1.0000e-05, -1.0000e-05]], grad_fn=<SubBackward0>)

# %%
import sys
patch_real = extract_affine_patches(timg, A, torch.arange(1), 32, 1.0)
plt.imshow(K.tensor_to_image(patch_real))

desc = calc_sift_descriptor(patch_real.mean(dim=1,keepdim=True), num_ang_bins, num_spatial_bins)
desc2 =  K.feature.SIFTDescriptor(32, num_ang_bins, num_spatial_bins)(patch_real.mean(dim=1,keepdim=True))
fig = visualize_sift(desc, num_ang_bins, num_spatial_bins, 'User SIFT')
fig2 = visualize_sift(desc2, num_ang_bins, num_spatial_bins, 'kornia SIFT')
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Provided tensor cannot contain a negative number!
# C:\Users\toell\OneDrive\Documents\GitHub\mpv-templates-backup\venv\Lib\site-packages\IPython\core\interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
